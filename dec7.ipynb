# %%
class Employee:
    def __init___(self, emp_id, name, designation, basic_salary):
        self.emp_id = emp_id
        self.name = name
        self.designation = designation
        self.basic_salary = basic_salary

    def calculate_gross_salary(self):
        da = 0.05 * self.basic_salary
        hra = 0.10 * self.basic_salary
        gross_salary = self.basic_salary + da + hra
        return gross_salary

    def calculate_net_salary(self):
        da = 0.05 * self.basic_salary
        hra = 0.10 * self.basic_salary
        lic_deduction = 0.03 * self.basic_salary
        pf_deduction = 0.08 * self.basic_salary

        gross_salary = self.calculate_gross_salary()
        net_salary = gross_salary - (lic_deduction + pf_deduction)

        return net_salary

    def display_details(self):
        print(f"Employee ID: {self.emp_id}")
        print(f"Name: {self.name}")
        print(f"Designation: {self.designation}")
        print(f"Basic Salary: {self.basic_salary}")
        print(f"Gross Salary: {self.calculate_gross_salary()}")
        print(f"Net Salary: {self.calculate_net_salary()}")


def main():
    emp_id = input("Enter employee ID: ")
    name = input("Enter employee name: ")
    designation = input("Enter employee designation: ")
    basic_salary = float(input("Enter basic salary: "))
    employee = Employee(emp_id, name, designation, basic_salary)
    print("\nEmployee Details:")
    employee.display_details()


if __name__ == "__main__":
    main()
# Out:
# Enter employee ID: 101
# Enter employee name: mahi
# Enter employee designation: web developer
# Enter basic salary: 40000
#
# Employee Details:
# Employee ID: 101
# Name: mahi
# Designation: web developer
# Basic Salary: 40000.0
# Gross Salary: 46000.0
# Net Salary: 41600.0

# %%
class employee:
    def __init__(self,emp_ed,name,designation,basic_salary):
        
        self.emp_id=emp_id
        self.name=name
        self.designation=designation
        self.basic_salary=basic_salary
    
    def calculate_gross_salary(self):
        da=0.05*self.basic_salary
        hra=0.10*sel.basic_salary
        gross_salary=baisc_salary+da+hra
        return gross_salary
    
    def calculate_net_salary(self):
        da=0.05*self.basic_salary
        hra=0.10*self.basic_salary
        lic_deduction=0.03*self.basic_salary
        pf_deduction=0.08*self.basic_salary
        gross_salary=self.calculate_gross_salary()
        net_salary=gross_salary-(lic_deduction+pf_deduction)
        return net_salary
    
    def display_details(self):
        print(f"employee id:{self.emp_id}")
        print(f"name:{self.name}")
        print(f"designation:{self.desigantion}")
        print(f"basic_salary:{self.basic_salary}")
        print(f"gross_salary:{self.gross_salary}")
        print(f"net_salary:{self.net_salary}")
        
    def main():
        emp_id=input("enter employee id")
        name=input("enter employee name")
        designation=input("enter employee designation")
        basic_salary=input("enter employee basic_salary")
        employee=employee(emp_id,name,designation,basic_salary)
        print("\nemployee details:")
        employee.display_details()

if __name__=="__main__":
       main()
# Out:
# Enter employee ID: 101
# Enter employee name: mahi
# Enter employee designation: hr
# Enter basic salary: 40000
#
# Employee Details:
# Employee ID: 101
# Name: mahi
# Designation: hr
# Basic Salary: 40000.0
# Gross Salary: 46000.0
# Net Salary: 41600.0

# %%
class Employee:
    def __init__(self):
        self.da=0
        self.hra=0
        self.pf=0
        self.lic=0
        self.gross=0
        self.deduct=0
        self.netSal=0
        
    def GetEmployee(self):
        self.empId=int(input("Enter the employee Number:"))
        self.name=input("Enter the name:")
        self.designation=input("Enter the designation:")
        self.salary=int(input("Enter the basic salary:"))
        
    def CalculateSal(self):
        self.__da=5/100*self.salary
        self.__hra=10/100*self.salary
                 
    def CalculateGrossSalary(self):
        self.__gross=self.salary+self.__da+self.__hra
        
    def CalculateDeduction(self):
        self.__lic=3/100*self.salary
        self.__pf=8/100*self.salary
        self.__deduct=self.__lic+self.__pf
        
    def CalculateNetSalary(self):
        self.__netSal=self.__gross-self.__deduct
            
    def Display(self):
       
        print(self.empId,"\t",self.name,"\t",self.designation,"\t",self.salary,"\t",self.__da,"\t ",self.__hra,"\t",self.__deduct,"\t",self.__gross,"\t",self.__netSal)


def bold_text(text):
    bold_start = '\033[1m'
    bold_end = '\033[0m'
    return bold_start + text + bold_end
    
n=int(input("Enter the no.of Employee:"))
EmpList=[]
for i in range(n):
    Emp=Employee()
    Emp.GetEmployee()
    Emp.CalculateSal()
    Emp.CalculateDeduction()
    Emp.CalculateGrossSalary()
    Emp.CalculateNetSalary()
    EmpList.append(Emp)

print(bold_text("Id \t EmpName\t Designation\tSalary\t DA \t HRA\t Deduction\t GrossSalary\t NetSalary"))
for e in EmpList:
    e.Display()
# Out:
# Enter the no.of Employee:3
# Enter the employee Number:101
# Enter the name:mahi
# Enter the designation:hr
# Enter the basic salary:40000
# Enter the employee Number:102
# Enter the name:abhi
# Enter the designation:md
# Enter the basic salary:50000
# Enter the employee Number:103
# Enter the name:adhi
# Enter the designation:ceo
# Enter the basic salary:60000
# Id 	 EmpName	 Designation	Salary	 DA 	 HRA	 Deduction	 GrossSalary	 NetSalary
# 101 	 mahi 	 hr 	 40000 	 2000.0 	  4000.0 	 4400.0 	 46000.0 	 41600.0
# 102 	 abhi 	 md 	 50000 	 2500.0 	  5000.0 	 5500.0 	 57500.0 	 52000.0
# 103 	 adhi 	 ceo 	 60000 	 3000.0 	  6000.0 	 6600.0 	 69000.0 	 62400.0
